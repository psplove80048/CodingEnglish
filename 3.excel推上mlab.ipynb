# %%
#coding=utf-8
import xlrd
import sys
import json
import pymongo
from pymongo import MongoClient

client=MongoClient("mongodb://Fantasylin:A1598753@ds151463.mlab.com:51463/english_bang")
db=client.english_bang
collection =db.Test

data=xlrd.open_workbook('1129-單字翻譯和句字翻譯.xlsx')  #匯入mlab資料
table=data.sheets()[0]

rowstag=table.row_values(0)
nrows=table.nrows
print (nrows) #資料筆數
returnData={}
for i in range(1,nrows):   #轉成dictionary再以json格式插入collection
    returnData[i]=json.dumps(dict(zip(rowstag,table.row_values(i)))) 
    returnData[i]=json.loads(returnData[i])
    collection.insert_one(returnData[i])
    
print ('done')
