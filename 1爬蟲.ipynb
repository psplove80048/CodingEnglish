# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup
from pdfminer.pdfinterp import PDFResourceManager, process_pdf
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from io import StringIO
import nltk

def readPDF(pdfFile):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, laparams=laparams)

    process_pdf(rsrcmgr, device, pdfFile)
    device.close()

    content = retstr.getvalue()
    retstr.close()
    return content

html=urlopen('https://cpe.cse.nsysu.edu.tw/cpe/test_data/problems')
bsobj=BeautifulSoup(html,'lxml')

temp=bsobj.find_all('a')
word=[]

for i in temp:
    if i.text=='pdf':
        pdfFile=urlopen(i.get('href'))
        ouptString=readPDF(pdfFile)
        pdfFile.close()
        
        token=nltk.word_tokenize(ouptString)
        word.append(token)
        
print(word)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8dbcf19cc703> in <module>()
#       1 from urllib.request import urlopen
#       2 from bs4 import BeautifulSoup
# ----> 3 from pdfminer.pdfinterp import PDFResourceManager, process_pdf
#       4 from pdfminer.converter import TextConverter
#       5 from pdfminer.layout import LAParams
#
# ModuleNotFoundError: No module named 'pdfminer'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# UVa 爬蟲 + pdfminer 現在可能不能用了
